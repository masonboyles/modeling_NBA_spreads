# %%
import pandas as pd

# %%
df = pd.read_csv('Predictions.csv')
def predict_result(spread: int):
    if spread>0:
        return 1
    else:
        return 0

# %%
df['Predicted_Result'] = df['SPREAD_PREDICTIONS'].apply(predict_result)
df['Actual_result'] = [1,1,1,1,1,0,1,0,0,1,0,0,0,1,0,1,0,x,x,x]
# Out:
#    predictions_final.game_matchup  SPREAD_PREDICTIONS  Predicted_Result
# 0                       ATL @ IND           21.232683                 1
# 1                       ATL @ MIN            9.798152                 1
# 2                       BKN @ NYK           11.323067                 1
# 3                       BKN @ PHI           -4.826933                 0
# 4                       BOS @ MIL           16.636267                 1
# 5                       CHA @ ATL           26.474088                 1
# 6                       CHA @ BOS           21.454373                 1
# 7                       CHA @ CLE           18.272817                 1
# 8                       CHI @ DET            5.110633                 1
# 9                       CHI @ NYK           12.215348                 1
# 10                      CHI @ WAS           -4.429567                 0
# 11                      DAL @ CHA          -13.856583                 0
# ...
